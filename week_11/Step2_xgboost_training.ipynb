# %%
#install the necessary libraries
# !pip install pyreadr xgboost scikit-learn
# Out:
# Collecting pyreadr
#   Downloading pyreadr-0.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyreadr) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.0->pyreadr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.0->pyreadr) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.0->pyreadr) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pyreadr) (1.17.0)
# Downloading pyreadr-0.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (411 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.7/411.7 kB 10.5 MB/s eta 0:00:00
# Installing collected packages: pyreadr
# Successfully installed pyreadr-0.5.3

# %%
#import libraries
import pyreadr
import xgboost as xgb
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# %%
# Defining the function to load all RDS files
def load_rds(filelocation):
    result = pyreadr.read_r(filelocation)
    df = result[None]  # The data is stored under key None when using the data reader from the pyreadr package.
    return df

# %%
# Develop a function to implement XGBoost training through 5-Fold CV.

def train_xgboost(df, size_label):
    # Here we will separate the predictors and the outcome
    X = df.drop('outcome', axis=1)
    y = df['outcome']

    # 5-Fold Stratified Cross Validation
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    # Now we define XGBoost model
    model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')

    # Record the start timing
    start_time = time.time()

    # Perform 5-Fold CV
    scores = cross_val_score(model, X, y, cv=skf, scoring='accuracy')

    # Record the end timing
    end_time = time.time()
    avg_accuracy = np.mean(scores)
    time_taken = end_time - start_time

    print(f"Dataset Size: {size_label}")
    print(f"Average 5-Fold CV Accuracy: {avg_accuracy:.4f}")
    print(f"Time Taken: {time_taken:.2f} seconds\n")

    return avg_accuracy, time_taken

# %%
# Now we are listing the dataset sizes
sizes = [100, 1000, 10000, 100000, 1000000, 10000000]

# %%
# Here we run the XGBOOST on all the datasets

results = []

for sz in sizes:
    filelocation = f"synthetic_data_{sz}.rds"  # No folder path needed, manually uploaded
    df = load_rds(filelocation)

    acc, timing = train_xgboost(df, size_label=sz)

    results.append({
        'Method Used': 'XGBoost (Python, scikit-learn, 5-fold CV)',
        'Dataset Size': sz,
        'Testing-set Predictive Performance': round(acc, 4),
        'Time Taken (seconds)': round(timing, 2)
    })
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Dataset Size: 100
# Average 5-Fold CV Accuracy: 0.8800
# Time Taken: 0.26 seconds
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Dataset Size: 1000
# Average 5-Fold CV Accuracy: 0.9490
# Time Taken: 0.32 seconds
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Dataset Size: 10000
# Average 5-Fold CV Accuracy: 0.9722
# Time Taken: 0.81 seconds
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Dataset Size: 100000
# Average 5-Fold CV Accuracy: 0.9872
# Time Taken: 5.82 seconds
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:16:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Dataset Size: 1000000
# Average 5-Fold CV Accuracy: 0.9919
# Time Taken: 41.72 seconds
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:17:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:18:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:20:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:21:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [00:23:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Dataset Size: 10000000
# Average 5-Fold CV Accuracy: 0.9931
# Time Taken: 443.42 seconds

# %%
# Now we display the final results table
results_df = pd.DataFrame(results)
results_df
# Out:
#                                  Method Used  Dataset Size  \
# 0  XGBoost (Python, scikit-learn, 5-fold CV)           100
# 1  XGBoost (Python, scikit-learn, 5-fold CV)          1000
# 2  XGBoost (Python, scikit-learn, 5-fold CV)         10000
# 3  XGBoost (Python, scikit-learn, 5-fold CV)        100000
# 4  XGBoost (Python, scikit-learn, 5-fold CV)       1000000
# 5  XGBoost (Python, scikit-learn, 5-fold CV)      10000000
#
#    Testing-set Predictive Performance  Time Taken (seconds)
# 0                              0.8800                  0.26
# 1                              0.9490                  0.32
# 2                              0.9722                  0.81
# 3                              0.9872                  5.82
# 4                              0.9919                 41.72
# 5                              0.9931                443.42
